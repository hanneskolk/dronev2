# %%
# 1. Setup
# !git clone https://github.com/<your_repo>
# %cd yolo-drone-system
# !pip install -r requirements.txt

# 2. Upload video
from google.colab import files
files.upload()

# 3. Move video
# !mv *.mp4 input_videos/

# 4. Run inference
# !python scripts/batch_infer.py

# 5. Download results
from google.colab import files
files.download("output_videos/output.mp4")
